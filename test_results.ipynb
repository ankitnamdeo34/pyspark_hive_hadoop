# %%
import pandas as pd
# import pyspark.sql.functions as F

# %%
df1 = pd.read_csv("dataset/train.csv")

# %%
# df2 = sqlContext.createDataFrame(df1)

# %%
df1
# Out:
#        patient_id                        name_of_drug  \
# 0          206461                           Valsartan
# 1           95260                          Guanfacine
# 2           92703                              Lybrel
# 3           35696            Buprenorphine / naloxone
# 4          155963                              Cialis
# 5           48928  Ethinyl estradiol / levonorgestrel
# 6           75612                      L-methylfolate
# 7          219869                       Amitriptyline
# 8          212077                         Lamotrigine
# 9           12372                             Atripla
# 10          41928                          Etanercept
# 11          96233                          Sertraline
# 12         206444                            Trilafon
# 13         221934                         Fluconazole
# 14         173398                          Clonazepam
# 15          12056                          Metaxalone
# ...

# %%
df1.review_by_patient = df1.review_by_patient.str.replace('"','',regex=True)

# %%
# df.withColumn(
#     "review_by_patient",
#     F.regexp_replace(F.col("review_by_patient"), '(")', '')
# )

# %%
df1.agg(['nunique', 'count', 'std', 'mean', "median", "min", "max", "mad"])
# Out:
#             patient_id                          name_of_drug  \
# nunique   32165.000000                                  2220
# count     32165.000000                                 32165
# std       67146.156602                                   NaN
# mean     115487.511052                                   NaN
# median   115776.000000                                   NaN
# min           9.000000  Abacavir / dolutegravir / lamivudine
# max      232289.000000                                  ella
# mad       58214.292755                                   NaN
#
#                                   use_case_for_drug  \
# nunique                                         636
# count                                         32165
# std                                             NaN
# mean                                            NaN
# median                                          NaN
# min      0</span> users found this comment helpful.
# ...

# %%
df1.columns
# Out:
# Index([u'patient_id', u'name_of_drug', u'use_case_for_drug',
#        u'review_by_patient', u'effectiveness_rating', u'drug_approved_by_UIC',
#        u'number_of_times_prescribed', u'base_score'],
#       dtype='object')

# %%
df1.groupby(["name_of_drug"]).agg(
    {
        'patient_id': ['nunique', 'count'],
        'effectiveness_rating': ['sum', 'std', 'mean', "median", "min", "max", "mad"],
        'number_of_times_prescribed': ['sum', 'std', 'mean', "median", "min", "max", "mad"],
        'base_score': ['sum', 'std', 'mean', "median", "min", "max", "mad"]
    }
).T
# Out:
# name_of_drug                        Abacavir / dolutegravir / lamivudine  \
# number_of_times_prescribed sum                                 82.000000
#                            std                                  7.565586
#                            mean                                11.714286
#                            median                              12.000000
#                            min                                  1.000000
#                            max                                 26.000000
#                            mad                                  4.612245
# base_score                 sum                                 41.356530
#                            std                                  1.325339
#                            mean                                 5.908076
#                            median                               6.355866
#                            min                                  3.471857
# ...

# %%
df1.groupby(["use_case_for_drug"]).agg(
    {
        'patient_id': ['nunique', 'count'],
        'effectiveness_rating': ['sum', 'std', 'mean', "median", "min", "max", "mad"],
        'number_of_times_prescribed': ['sum', 'std', 'mean', "median", "min", "max", "mad"],
        'base_score': ['sum', 'std', 'mean', "median", "min", "max", "mad"]
    }
).T
# Out:
# use_case_for_drug                   0</span> users found this comment helpful.  \
# number_of_times_prescribed sum                                        0.000000
#                            std                                        0.000000
#                            mean                                       0.000000
#                            median                                     0.000000
#                            min                                        0.000000
#                            max                                        0.000000
#                            mad                                        0.000000
# base_score                 sum                                       92.765629
#                            std                                        1.580660
#                            mean                                       4.882402
#                            median                                     5.361012
# ...

# %%
df1.groupby(["drug_approved_by_UIC"]).agg(
    {
        'patient_id': ['nunique', 'count'],
        'effectiveness_rating': ['sum', 'std', 'mean', "median", "min", "max", "mad"],
        'number_of_times_prescribed': ['sum', 'std', 'mean', "median", "min", "max", "mad"],
        'base_score': ['sum', 'std', 'mean', "median", "min", "max", "mad"]
    }
).T
# Out:
# drug_approved_by_UIC                  1-Apr-08    1-Apr-09   1-Apr-10  \
# number_of_times_prescribed sum      650.000000  257.000000  44.000000
#                            std      113.998660   65.725185   8.485281
#                            mean      72.222222   51.400000  22.000000
#                            median    19.000000   26.000000  22.000000
#                            min        7.000000   10.000000  16.000000
#                            max      357.000000  168.000000  28.000000
#                            mad       76.123457   46.640000   6.000000
# base_score                 sum       61.968056   34.761381  16.698711
#                            std        0.925177    1.716748   0.653533
#                            mean       6.885340    6.952276   8.349355
#                            median     7.095402    7.647573   8.349355
#                            min        5.305232    4.102312   7.887238
# ...

# %%
df1.groupby(["name_of_drug", "use_case_for_drug", "drug_approved_by_UIC"]).agg(
    {
        'patient_id': ['nunique', 'count'],
        'effectiveness_rating': ['sum', 'std', 'mean', "median", "min", "max", "mad"],
        'number_of_times_prescribed': ['sum', 'std', 'mean', "median", "min", "max", "mad"],
        'base_score': ['sum', 'std', 'mean', "median", "min", "max", "mad"]
    }
).T
# Out:
# name_of_drug                       Abacavir / dolutegravir / lamivudine  \
# use_case_for_drug                                         HIV Infection
# drug_approved_by_UIC                                          15-Aug-16
# number_of_times_prescribed sum                                 1.000000
#                            std                                      NaN
#                            mean                                1.000000
#                            median                              1.000000
#                            min                                 1.000000
#                            max                                 1.000000
#                            mad                                 0.000000
# base_score                 sum                                 4.878172
#                            std                                      NaN
#                            mean                                4.878172
# ...

# %%
df1.groupby(["name_of_drug", "use_case_for_drug"]).agg(
    {
        'patient_id': ['nunique', 'count'],
        'effectiveness_rating': ['sum', 'std', 'mean', "median", "min", "max", "mad"],
        'number_of_times_prescribed': ['sum', 'std', 'mean', "median", "min", "max", "mad"],
        'base_score': ['sum', 'std', 'mean', "median", "min", "max", "mad"]
    }
).T
# Out:
# name_of_drug                       Abacavir / dolutegravir / lamivudine  \
# use_case_for_drug                                         HIV Infection
# number_of_times_prescribed sum                                82.000000
#                            std                                 7.565586
#                            mean                               11.714286
#                            median                             12.000000
#                            min                                 1.000000
#                            max                                26.000000
#                            mad                                 4.612245
# base_score                 sum                                41.356530
#                            std                                 1.325339
#                            mean                                5.908076
#                            median                              6.355866
# ...

# %%
df1.groupby(["name_of_drug", "drug_approved_by_UIC"]).agg(
    {
        'patient_id': ['nunique', 'count'],
        'effectiveness_rating': ['sum', 'std', 'mean', "median", "min", "max", "mad"],
        'number_of_times_prescribed': ['sum', 'std', 'mean', "median", "min", "max", "mad"],
        'base_score': ['sum', 'std', 'mean', "median", "min", "max", "mad"]
    }
).T
# Out:
# name_of_drug                       Abacavir / dolutegravir / lamivudine  \
# drug_approved_by_UIC                                          15-Aug-16
# number_of_times_prescribed sum                                 1.000000
#                            std                                      NaN
#                            mean                                1.000000
#                            median                              1.000000
#                            min                                 1.000000
#                            max                                 1.000000
#                            mad                                 0.000000
# base_score                 sum                                 4.878172
#                            std                                      NaN
#                            mean                                4.878172
#                            median                              4.878172
# ...

# %%
df1.corr()
# Out:
#                             patient_id  effectiveness_rating  \
# patient_id                    1.000000              0.018803
# effectiveness_rating          0.018803              1.000000
# number_of_times_prescribed    0.017499              0.242224
# base_score                    0.010924              0.412301
#
#                             number_of_times_prescribed  base_score
# patient_id                                    0.017499    0.010924
# effectiveness_rating                          0.242224    0.412301
# number_of_times_prescribed                    1.000000    0.134295
# base_score                                    0.134295    1.000000

# %%
df1[["effectiveness_rating", "number_of_times_prescribed", "base_score"]].corr()
# Out:
#                             effectiveness_rating  number_of_times_prescribed  \
# effectiveness_rating                    1.000000                    0.242224
# number_of_times_prescribed              0.242224                    1.000000
# base_score                              0.412301                    0.134295
#
#                             base_score
# effectiveness_rating          0.412301
# number_of_times_prescribed    0.134295
# base_score                    1.000000

# %%
df1[["effectiveness_rating", "base_score"]].corr()
# Out:
#                       effectiveness_rating  base_score
# effectiveness_rating              1.000000    0.412301
# base_score                        0.412301    1.000000

# %%
df1[["number_of_times_prescribed", "base_score"]].corr()
# Out:
#                             number_of_times_prescribed  base_score
# number_of_times_prescribed                    1.000000    0.134295
# base_score                                    0.134295    1.000000

# %%
df1[["number_of_times_prescribed", "effectiveness_rating"]].corr()
# Out:
#                             number_of_times_prescribed  effectiveness_rating
# number_of_times_prescribed                    1.000000              0.242224
# effectiveness_rating                          0.242224              1.000000
